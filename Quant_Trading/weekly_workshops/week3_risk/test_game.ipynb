# %%
from utils.monte_carlo_games import NominalMonteCarlo, PercentageMonteCarlo

# %%
mc = NominalMonteCarlo(n_simulations=1000, bet=20.0, multiplier=1, odds=0.51,
                       initial_amount=100, n_bets=30, plot=True, log=True)
mean_final, fail_rate = mc.monte_carlo_simulation()
# Out:
# Mean return of the strategy: 11.48%
#
# How often we run out of money: 32.6%

# %%
mc = PercentageMonteCarlo(n_simulations=1000, bet=0.1, multiplier=1, odds=0.51,
                       initial_amount=100, n_bets=30, plot=True, log=True, threshold=0.5)
mean_final, fail_rate = mc.monte_carlo_simulation()
# Out:
# Mean return of the strategy: 8.382547757769373%
#
# How often we run out of money: 13.4%
